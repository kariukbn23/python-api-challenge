# %%
#Import necessary dependencies. The last dependency is a style format for matplot lib graphs that will done towards the end of this script. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import requests 
import csv 
import seaborn as sb

# %%
# Per instructions we needed to create a file path for our output data to be stored. What should appear in this file by the end of this code will be a data frame of the information collected
City_data_file = "Resources/City_Data.csv"

# %%
# need to import citipy to help tag geo coordinates to cities selected
from citipy import citipy

# %%
# import my individualized API key and define desired units for temperature because I will need to successfuly call url 
from BK_api_key import BK_api_key

temperature_units = "imperial"

# %%
# Prior to any list creation or defining range for specific values we will look for, I need make sure my query_url works. Base url was provided from OpenWeatherMap recommendations on how to perform successful API call 
url_query = f"http://api.openweathermap.org/data/2.5/weather?appid={BK_api_key}&units={temperature_units}&q="

# %%
# Since we will be capturing the lat and long of the random cities I will need define ranges for those values and create an open list to add those values later on. Range values are based on researched max and min values for lat and long  

latitude_range = (-90, 90)
longitude_range = (-180, 180)


latit_and_longtit_list = []
cities = []

# %%
#From starter code
# Need to use np module to generate selection of the random cities and for those to be stored in the open lists I created above. Obviously what's different is how I named my variables.
latitude_values = np.random.uniform(low=-90.000, high=90.000, size=1500)
longitude_values = np.random.uniform(low=-180.000, high=180.000, size=1500)

latit_and_longtit_list = zip(latitude_values, longitude_values)

# For loop to capture lats and longs for the randomnly selected cities captured
for latit_and_longtit_list in latit_and_longtit_list:
    city = citipy.nearest_city(latit_and_longtit_list[0], latit_and_longtit_list[1]).city_name
    
    # Conditional statement to ensure non-repeat data points are added to the data sets. This is an alternative to the dropna function i've used in the past. 
    if city not in cities:
        cities.append(city)

    # Print the city to confirm at least 500 cities were selected.
len(cities)
# Out:
# 604

# %%
#Double check to ensure actual city values were gathered from citipy module.
print(cities)
# Out:
# ['hilo', 'svetlogorsk', 'san jose', 'codrington', 'shkotovo-26', 'rehoboth', 'busselton', 'burica', 'bluff', 'mys shmidta', 'ushuaia', 'puerto ayora', 'sheridan', 'datong', 'palana', 'khatanga', 'tasiilaq', 'qaanaaq', 'joshimath', 'bethel', 'cabo san lucas', 'klaksvik', 'albany', 'zlobin', 'castlegar', 'saint-georges', 'cherskiy', 'vaini', 'hermanus', 'rikitea', 'ancud', 'termiz', 'atuona', 'tuktoyaktuk', 'sol-iletsk', 'bredasdorp', 'tarana', 'ilulissat', 'rio gallegos', 'bedele', 'cape town', 'kodiak', 'barrow', 'esso', 'javanrud', 'mataura', 'afmadu', 'illoqqortoormiut', 'fort-shevchenko', 'talnakh', 'east london', 'khonsa', 'saint george', 'kapaa', 'warmbad', 'rawah', 'ialibu', 'bracebridge', 'ninohe', 'poya', 'marcona', 'saint-philippe', 'stromness', 'taolanaro', 'zhuhai', 'padang', 'saskylakh', 'katete', 'pisco', 'katsuura', 'attawapiskat', 'bulgan', 'high level', 'new norfolk', 'teya', 'mandalgovi', 'muisne', 'doctor pedro p. pena', 'ozernovskiy', 'altay', 'tabiauea', 'taoudenni', 'bambous virieux', 'thalassery', 'karratha', 'punta arenas', 'guadalajara', 'thompson', 'ust-barguzin', 'yining', 'salto', 'port-gentil', 'port alfred', 'kismayo', 'belushya guba', 'ribeira grande', 'acapulco', 'acajutla', 'daru', 'san cristobal', 'sola', 'zhezkazgan', 'san pedro', 'butaritari', 'bengkulu', 'iqaluit', 'gravdal', 'amderma', 'port hardy', 'offa', 'carnarvon', 'zhangye', 'hobart', 'nome', 'hryshkivtsi', 'tumannyy', 'mahebourg', 'malanje', 'russell', 'graciano sanchez', 'tres arroyos', 'arraial do cabo', 'makat', 'havre-saint-pierre', 'flinders', 'daxian', 'kavieng', 'hervey bay', 'saint-francois', 'sechura', 'constitucion', 'castro', 'erenhot', 'mar del plata', 'lagoa', 'chulman', 'jalu', 'puerto lempira', 'nanortalik', 'navlya', 'necochea', 'porto novo', 'khasan', 'dikson', 'trinidad', 'zhetybay', 'oktyabrskoye', 'honningsvag', 'geraldton', 'hithadhoo', 'syracuse', 'la sarre', 'thunder bay', 'husavik', 'mokobeng', 'sentyabrskiy', 'atar', 'kruisfontein', 'nabire', 'jamestown', 'rocha', 'isangel', 'salalah', 'hamilton', 'sioux lookout', 'fort nelson', 'black diamond', 'joensuu', 'marystown', 'radishchevo', 'aligudarz', 'demirci', 'clyde river', 'avarua', 'longyearbyen', 'kano', 'vila velha', 'dulce grande', 'alekseyevsk', 'save', 'chingirlau', 'kieta', 'talcahuano', 'leh', 'ironton', 'wenling', 'ponta do sol', 'whitefish', 'san jeronimo', 'nouadhibou', 'tilichiki', 'oranjemund', 'souillac', 'naze', 'touros', 'honiara', 'maceio', 'hwange', 'raudeberg', 'kathu', 'nikolskoye', 'launceston', 'babanusah', 'ulladulla', 'guerrero negro', 'grand river south east', 'clarksburg', 'conceicao da barra', 'sitka', 'tsihombe', 'paita', 'cidreira', 'abu samrah', 'la ronge', 'tocache', 'faya', 'itoman', 'gizo', 'talagang', 'esperance', 'mizpe ramon', 'muros', 'amapa', 'carolina', 'muzhi', 'georgetown', 'tungor', 'sangar', 'dotnuva', 'sao filipe', 'mokhsogollokh', 'mehamn', 'kysyl-syr', 'lavrentiya', 'longlac', 'kedrovyy', 'narsaq', 'barentsburg', 'haines junction', 'kaitangata', 'mabaruma', 'alofi', 'walvis bay', 'port elizabeth', 'richards bay', 'qaqortoq', 'dunedin', 'zakamensk', 'jacareacanga', 'sumbawa', 'zemio', 'hay river', 'margate', 'the valley', 'lukulu', 'manzhouli', 'carthage', 'zhigansk', 'plouzane', 'kloulklubed', 'pevek', 'pandan niog', 'sabirabad', 'aklavik', 'kasongo-lunda', 'port macquarie', 'cap malheureux', 'pokaran', 'yellowknife', 'yingcheng', 'aranos', 'okha', 'goderich', 'payson', 'banjar', 'vostok', 'kortkeros', 'ayapel', 'eau claire', 'coquimbo', 'sao jose da coroa grande', 'alexandria', 'severnoye', 'upernavik', 'ternate', 'riachao das neves', 'usinsk', 'tiksi', 'broken hill', 'khandyga', 'puerto escondido', 'tornio', 'lakhdenpokhya', 'tual', 'impfondo', 'akom', 'bonthe', 'bud', 'devonport', 'acarau', 'kachiry', 'hasaki', 'baherden', 'daugavpils', 'khorramshahr', 'madison', 'samusu', 'leningradskiy', 'shimoda', 'belaya gora', 'kaputa', 'lishan', 'luganville', 'nantucket', 'tacna', 'morgantown', 'mount pleasant', 'nemuro',  ...

# %%
# I then created an initial data frame for these cities to be stored in. 
Project_Primary_df = pd.DataFrame(cities)

# %%
# Further breakdown of the data frame I needed to create to store the list of cities gathered from the citipy command. I first decided to choose a sample of 600 cities because the minimum requirement was 500. I think reset the index for the data frame to the different cities that were collected in the list. From there I just renamed each of the column values to required fileds of information that we would be calling from the API. Performed a .head() to ensure that my data frame was set up correctly. 
Project_Secondary_df = Project_Primary_df.sample(600)
Project_Secondary_df = Project_Secondary_df.reset_index(drop = True)
Project_Secondary_df.columns = ["City"]
Project_Secondary_df.index += 1 
Project_Secondary_df["Latitudes"] = ""
Project_Secondary_df["Longitudes"] = ""
Project_Secondary_df["Country"] = ""
Project_Secondary_df["Date"] = ""
Project_Secondary_df["Temp Max"] = ""
Project_Secondary_df["Humidity"] = ""
Project_Secondary_df["Cloudiness"] = ""
Project_Secondary_df["Wind Speed"] = ""
Project_Secondary_df.head()
# Out:
#                 City Latitudes Longitudes Country Date Temp Max Humidity  \
# 1             balimo
# 2           olafsvik
# 3      alta floresta
# 4  riachao das neves
# 5        east london
#
#   Cloudiness Wind Speed
# 1
# 2
# 3
# 4
# 5

# %%
# After multiple failed attempts in trying to run a for loop for 'city in cities', I was able to figure out that I could run a for loop that was predicated on the index set in the data frame above. From there the loop would run the iterative commands to collect each of the specific data points I needed from the API call. I was able to figure out what tags from the API call to put in my code by first running the call in json on the first couple of cities. One thing I did have to research was how to remove the spaces ("") from my json script. 
#The only thing I was unable to do was to group my processing records in differents sets of 50 like the exemplar. Instead I printed off my processing records based off my index values which I preset in the data frame above. 
for index,row in Project_Secondary_df.iterrows():
    try: 
        city_names = row["City"]
        response = requests.get(url_query + city_names.replace(" ","%20")).json()
        Project_Secondary_df.set_value(index,"Latitudes",response.get("coord",{}).get("lat"))
        Project_Secondary_df.set_value(index,"Longitudes",response.get("coord",{}).get("lon"))
        Project_Secondary_df.set_value(index,"Country",response.get("sys",{}).get("country"))
        Project_Secondary_df.set_value(index,"Date",response.get("dt",{}))
        Project_Secondary_df.set_value(index,"Temp Max",response.get("main",{}).get("temp_max"))
        Project_Secondary_df.set_value(index,"Humidity",response.get("main",{}).get("humidity"))
        Project_Secondary_df.set_value(index,"Cloudiness",response.get("clouds",{}).get("all"))
        Project_Secondary_df.set_value(index,"Wind Speed",response.get("wind",{}).get("speed"))
        print("Processing Record " + str(index) + " of 600 | " + str(city_names))
    except Exception:
        print("City not found. Skipping...")
print("-------------------------\nData Retrieval Complete\n-------------------------")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# Processing Record 1 of 600 | balimo
# Processing Record 2 of 600 | olafsvik
# Processing Record 3 of 600 | alta floresta
# Processing Record 4 of 600 | riachao das neves
# Processing Record 5 of 600 | east london
# Processing Record 6 of 600 | mocambique
# Processing Record 7 of 600 | thalassery
# Processing Record 8 of 600 | hohhot
# Processing Record 9 of 600 | kavieng
# Processing Record 10 of 600 | guadalajara
# Processing Record 11 of 600 | lanigan
# Processing Record 12 of 600 | saleaula
# Processing Record 13 of 600 | zlobin
# Processing Record 14 of 600 | lagoa
# Processing Record 15 of 600 | pevek
# Processing Record 16 of 600 | ushuaia
# Processing Record 17 of 600 | coihaique
# Processing Record 18 of 600 | te anau
# Processing Record 19 of 600 | fort nelson
# Processing Record 20 of 600 | ironton
# Processing Record 21 of 600 | ternate
# Processing Record 22 of 600 | fort madison
# Processing Record 23 of 600 | san carlos de bariloche
# Processing Record 24 of 600 | henties bay
# Processing Record 25 of 600 | louisbourg
# Processing Record 26 of 600 | north platte
# Processing Record 27 of 600 | dzhusaly
# Processing Record 28 of 600 | nabire
# Processing Record 29 of 600 | atar
# Processing Record 30 of 600 | carolina
# Processing Record 31 of 600 | ubinskoye
# Processing Record 32 of 600 | kamenskoye
# Processing Record 33 of 600 | anadyr
# Processing Record 34 of 600 | arraial do cabo
# Processing Record 35 of 600 | kasongo-lunda
# Processing Record 36 of 600 | tuatapere
# Processing Record 37 of 600 | kortkeros
# Processing Record 38 of 600 | pandan niog
# Processing Record 39 of 600 | vaini
# Processing Record 40 of 600 | goumeron
# Processing Record 41 of 600 | macas
# Processing Record 42 of 600 | baherden
# Processing Record 43 of 600 | oskaloosa
# Processing Record 44 of 600 | daru
# Processing Record 45 of 600 | havre-saint-pierre
# Processing Record 46 of 600 | doctor pedro p. pena
# Processing Record 47 of 600 | punta arenas
# Processing Record 48 of 600 | constitucion
# Processing Record 49 of 600 | vikhorevka
# Processing Record 50 of 600 | karratha
# Processing Record 51 of 600 | geraldton
# Processing Record 52 of 600 | husavik
# Processing Record 53 of 600 | busselton
# Processing Record 54 of 600 | dotnuva
# Processing Record 55 of 600 | kieta
# Processing Record 56 of 600 | faanui
# Processing Record 57 of 600 | esso
# Processing Record 58 of 600 | chulman
# Processing Record 59 of 600 | souillac
# Processing Record 60 of 600 | oktyabrskiy
# Processing Record 61 of 600 | black diamond
# Processing Record 62 of 600 | hermanus
# Processing Record 63 of 600 | dunedin
# Processing Record 64 of 600 | galiwinku
# Processing Record 65 of 600 | vaitupu
# Processing Record 66 of 600 | alofi
# Processing Record 67 of 600 | cumpas
# Processing Record 68 of 600 | palmer
# Processing Record 69 of 600 | airai
# Processing Record 70 of 600 | mar del plata
# Processing Record 71 of 600 | santa rosalia
# Processing Record 72 of 600 | mataura
# Processing Record 73 of 600 | amderma
# Processing Record 74 of 600 | kloulklubed
# Processing Record 75 of 600 | muzhi
# Processing Record 76 of 600 | havoysund
# Processing Record 77 of 600 | kapaa
# Processing Record 78 of 600 | nouadhibou
# Processing Record 79 of 600 | kuusamo
# Processing Record 80 of 600 | asau
# Processing Record 81 of 600 | berlevag
# Processing Record 82 of 600 | zhigansk
# Processing Record 83 of 600 | petatlan
# Processing Record 84 of 600 | okhotsk
# Processing Record 85 of 600 | isangel
# Processing Record 86 of 600 | tutoia
# Processing Record 87 of 600 | pangnirtung
# Processing Record 88 of 600 | linkou
# Processing Record 89 of 600 | paita
# Processing Record 90 of 600 | katete
# Processing Record 91 of 600 | woodward
# Processing Record 92 of 600 | oktyabrskoye
# Processing Record 93 of 600 | norrtalje
# Processing Record 94 of 600 | khandyga
# Processing Record 95 of 600 | mutoko
# Processing Record 96 of 600 | half moon bay
# Processing Record 97 of 600 | chokurdakh
# Processing Record 98 of 600 | alekseyevsk
# Processing Record 99 of 600 | albany
# Processing Record 100 of 600 | acajutla
# Processing Record 101 of 600 | tasiilaq
# Processing Record 102 of 600 | west bay
# Processing Record 103 of 600 | aranos
# Processing Record 104 of 600 | salto
# Processing Record 105 of 600 | ballina
# Processing Record 106 of 600 | hwange
# Processing Record 107 of 600 | pokaran
# Processing Record 108 of 600 | nikolskoye
# Processing Record 109 of 600 | honningsvag
# Processing Record 110 of 600 | aripuana
# Processing Record 111 of 600 | hamilton
# Processing Record 112 of 600 | mys shmidta
# Processing Record 113 of 600 | coruripe
# Processing Record 114 of 600 | mikkeli
# Processing Record 115 of 600 | murud
# Processing Record 116 of 600 | kurchum
# Processing Record 117 of 600 | meulaboh
# Processing Record 118 of 600 | grand river south east
# Processing Record 119 of 600 | pemangkat
# Processing Record 120 of 600 | kodiak
# Processing Record 121 of 600 | kandrian
# Processing Record 122 of 600 | tual
# Processing Record 123 of 600 | ahipara
# Processing Record 124 of 600 | emerald
# Processing Record 125 of 600 | touros
# Processing Record 126 of 600 | samusu
# Processing Record 127 of 600 | muzquiz
# Processing Record 128 of 600 | conceicao das alagoas
# Processing Record 129 of 600 | mandera
# Processing Record 130 of 600 | ozernovskiy
# Processing Record 131 of 600 | paredon
# Processing Record 132 of 600 | sheridan
# Processing Record 133 of 600 | teya
# Processing Record 134 of 600 | mizpe ramon
# Processing Record 135 of 600 | morant bay
# Processing Record 136 of 600 | joshimath
# Processing Record 137 of 600 | ostrovnoy
# Processing Record 138 of 600 | raudeberg
# Processing Record 139 of 600 | tsihombe
# Processing Record 140 of 600 | cherskiy
# Processing Record 141 of 600 | vangaindrano
# Processing Record 142 of 600 | rio gallegos
# Processing Record 143 of 600 | truth or consequences
# Processing Record 144 of 600 | mokobeng
# Processing Record 145 of 600 | carnarvon
# Processing Record 146 of 600 | bandarbeyla
# Processing Record 147 of 600 | san andres
# Processing Record 148 of 600 | neiafu
# Processing Record 149 of 600 | srandakan
# Processing Record 150 of 600 | seoul
# Processing Record 151 of 600 | oranjemund
# Processing Record 152 of 600 | maniitsoq
# Processing Record 153 of 600 | yining
# Processing Record 154 of 600 | salalah
# Processing Record 155 of 600 | ayapel
# Processing Record 156 of 600 | kismayo
# Processing Record 157 of 600 | yichun
# Processing Record 158 of 600 | illoqqortoormiut
# Processing Record 159 of 600 | victor harbor
# Processing Record 160 of 600 | kedrovyy
# Processing Record 161 of 600 | sitka
# Processing Record 162 of 600 | zhangye
# Processing Record 163 of 600 | anilao
# Processing Record 164 of 600 | hithadhoo
# Processing Record 165 of 600 | berezovka
# Processing Record 166 of 600 | plouzane
# Processing Record 167 of 600 | lavrentiya
# Processing Record 168 of 600 | sept-iles
# Processing Record 169 of 600 | omboue
# Processing Record 170 of 600 | graciano sanchez
# Processing Record 171 of 600 | guerrero negro
# Processing Record 172 of 600 | tres arroyos
# Processing Record 173 of 600 | boa vista
# Processing Record 174 of 600 | afmadu
# Processing Record 175 of 600 | yellowknife
# Processing Record 176 of 600 | nantucket
# Processing Record 177 of 600 | garowe
# Processing Record 178 of 600 | rehoboth
# Processing Record 179 of 600 | talnakh
# Processing Record 180 of 600 | seymchan
# Processing Record 181 of 600 | skalistyy
# Processing Record 182 of 600 | clarksburg
# Processing Record 183 of 600 | bandarban
# Processing Record 184 of 600 | usinsk
# Processing Record 185 of 600 | barrow
# Processing Record 186 of 600 | barentsburg
# Processing Record 187 of 600 | vardo
# Processing Record 188 of 600 | tarana
# Processing Record 189 of 600 | altay
# Processing Record 190 of 600 | cabo san lucas
# Processing Record 191 of 600 | praia da vitoria
# Processing Record 192 of 600 | erenhot
# Processing Record 193 of 600 | goderich
# Processing Record 194 of 600 | ancud
# Processing Record 195 of 600 | santa rosa
# Processing Record 196 of 600 | halalo
# Processing Record 197 of 600 | muisne
# Processing Record 198 of 600 | zhezkazgan
# Processing Record 199 of 600 | mehamn
# Processing Record 200 of 600 | termiz
# Processing Record 201 of 600 | mehran
# Processing Record 202 of 600 | melekhovskaya
# Processing Record 203 of 600 | safaqis
# Processing Record 204 of 600 | sale
# Processing Record 205 of 600 | solton
# Processing Record 206 of 600 | tornio
# Processing Record 207 of 600 | san jeronimo
# Processing Record 208 of 600 | warmbad
# Processing Record 209 of 600 | lorengau
# Processing Record 210 of 600 | los llanos de aridane
# Processing Record 211 of 600 | manaure
# Processing Record 212 of 600 | yuksekova
# Processing Record 213 of 600 | hofn
# Processing Record 214 of 600 | buqayq
# Processing Record 215 of 600 | bundaberg
# Processing Record 216 of 600 | khatanga
# Processing Record 217 of 600 | atuona
# Processing Record 218 of 600 | egvekinot
# Processing Record 219 of 600 | iqaluit
# Processing Record 220 of 600 | amudalavalasa
# Processing Record 221 of 600 | jurado
# Processing Record 222 of 600 | trinidad
# Processing Record 223 of 600 | bengkulu
# Processing Record 224 of 600 | hagenow
# Processing Record 225 of 600 | tumannyy
# Processing Record 226 of 600 | batesville
# Processing Record 227 of 600 | jaisalmer
# Processing Record 228 of 600 | nome
# Processing Record 229 of 600 | kahului
# Processing Record 230 of 600 | turukhansk
# Processing Record 231 of 600 | poya
# Processing Record 232 of 600 | tungor
# Processing Record 233 of 600 | chuy
# Processing Record 234 of 600 | tezu
# Processing Record 235 of 600 | vao
# Processing Record 236 of 600 | olavarria
# Processing Record 237 of 600 | mahebourg
# Processing Record 238 of 600 | codrington
# Processing Record 239 of 600 | bowen
# Processing Record 240 of 600 | acapulco
# Processing Record 241 of 600 | adrar
# Processing Record 242 of 600 | xingtai
# Processing Record 243 of 600 | dikson
# Processing Record 244 of 600 | tocache
# Processing Record 245 of 600 | ferme-neuve
# Processing Record 246 of 600 | naze
# Processing Record 247 of 600 | mecca
# Processing Record 248 of 600 | daugavpils
# Processing Record 249 of 600 | lukulu
# Processing Record 250 of 600 | butaritari
# Processing Record 251 of 600 | la ronge
# Processing Record 252 of 600 | arkhara
# Processing Record 253 of 600 | save
# Processing Record 254 of 600 | talagang
# Processing Record 255 of 600 | qaanaaq
# Processing Record 256 of 600 | thompson
# Processing Record 257 of 600 | wenling
# Processing Record 258 of 600 | bambous virieux
# Processing Record 259 of 600 | navlya
# Processing Record 260 of 600 | port blair
# Processing Record 261 of 600 | jumla
# Processing Record 262 of 600 | ratnagiri
# Processing Record 263 of 600 | acarau
# Processing Record 264 of 600 | babanusah
# Processing Record 265 of 600 | bluff
# Processing Record 266 of 600 | padang
# Processing Record 267 of 600 | marystown
# Processing Record 268 of 600 | rikitea
# Processing Record 269 of 600 | aligudarz
# Processing Record 270 of 600 | the valley
# Processing Record 271 of 600 | joensuu
# Processing Record 272 of 600 | inuvik
# Processing Record 273 of 600 | ilulissat
# Processing Record 274 of 600 | akom
# Processing Record 275 of 600 | clyde river
# Processing Record 276 of 600 | tuktoyaktuk
# Processing Record 277 of 600 | ust-uda
# Processing Record 278 of 600 | necochea
# Processing Record 279 of 600 | chingirlau
# Processing Record 280 of 600 | jacareacanga
# Processing Record 281 of 600 | fort saint john
# Processing Record 282 of 600 | sioux lookout
# Processing Record 283 of 600 | prince rupert
# Processing Record 284 of 600 | beringovskiy
# Processing Record 285 of 600 | leningradskiy
# Processing Record 286 of 600 | deputatskiy
# Processing Record 287 of 600 | ninohe
# Processing Record 288 of 600 | stoughton
# Processing Record 289 of 600 | puerto lempira
# Processing Record 290 of 600 | susa
# Processing Record 291 of 600 | kaihua
# Processing Record 292 of 600 | ust-barguzin
# Processing Record 293 of 600 | kavaratti
# Processing Record 294 of 600 | shimoda
# Processing Record 295 of 600 | san patricio
# Processing Record 296 of 600 | vostok
# Processing Record 297 of 600 | vaitape
# Processing Record 298 of 600 | sovetskiy
# Processing Record 299 of 600 | saint-georges
# Processing Record 300 of 600 | fortuna
# Processing Record 301 of 600 | kachiry
# Processing Record 302 of 600 | offa
# Processing Record 303 of 600 | payson
# Processing Record 304 of 600 | farmington
# Processing Record 305 of 600 | dulce grande
# Processing Record 306 of 600 | requena
# Processing Record 307 of 600 | aguimes
# Processing Record 308 of 600 | datong
# Processing Record 309 of 600 | sumbawa
# Processing Record 310 of 600 | bracebridge
# Processing Record 311 of 600 | broken hill
# Processing Record 312 of 600 | moussoro
# Processing Record 313 of 600 | tiksi
# Processing Record 314 of 600 | banda aceh
# Processing Record 315 of 600 | port-gentil
# Processing Record 316 of 600 | zhuhai
# Processing Record 317 of 600 | sentyabrskiy
# Processing Record 318 of 600 | saint george
# Processing Record 319 of 600 | chipinge
# Processing Record 320 of 600 | rawlins
# Processing Record 321 of 600 | homer
# Processing Record 322 of 600 | pueblo bello
# Processing Record 323 of 600 | morehead
# Processing Record 324 of 600 | jos
# Processing Record 325 of 600 | khonsa
# Processing Record 326 of 600 | qrendi
# Processing Record 327 of 600 | waddan
# Processing Record 328 of 600 | saint-philippe
# Processing Record 329 of 600 | taoudenni
# Processing Record 330 of 600 | doha
# Processing Record 331 of 600 | avera
# Processing Record 332 of 600 | kathu
# Processing Record 333 of 600 | port macquarie
# Processing Record 334 of 600 | avarua
# Processing Record 335 of 600 | martinsicuro
# Processing Record 336 of 600 | zakamensk
# Processing Record 337 of 600 | poum
# Processing Record 338 of 600 | jaen
# Processing Record 339 of 600 | inirida
# Processing Record 340 of 600 | amapa
# Processing Record 341 of 600 | stromness
# Processing Record 342 of 600 | kysyl-syr
# Processing Record 343 of 600 | ballitoville
# Processing Record 344 of 600 | jamestown
# Processing Record 345 of 600 | belushya guba
# Processing Record 346 of 600 | okha
# Processing Record 347 of 600 | ponta do sol
# Processing Record 348 of 600 | port lincoln
# Processing Record 349 of 600 | sao jose da coroa grande
# Processing Record 350 of 600 | lata
# Processing Record 351 of 600 | davenda
# Processing Record 352 of 600 | tateyama
# Processing Record 353 of 600 | attawapiskat
# Processing Record 354 of 600 | ambatondrazaka
# Processing Record 355 of 600 | ulladulla
# Processing Record 356 of 600 | tinaquillo
# Processing Record 357 of 600 | sao filipe
# Processing Record 358 of 600 | meyungs
# Processing Record 359 of 600 | abha
# Processing Record 360 of 600 | russell
# Processing Record 361 of 600 | tacna
# Processing Record 362 of 600 | javanrud
# Processing Record 363 of 600 | tigzirt
# Processing Record 364 of 600 | santiago
# Processing Record 365 of 600 | kenai
# Processing Record 366 of 600 | karamay
# Processing Record 367 of 600 | pamekasan
# Processing Record 368 of 600 | belyy yar
# Processing Record 369 of 600 | udachnyy
# Processing Record 370 of 600 | alto araguaia
# Processing Record 371 of 600 | si bun ruang
# Processing Record 372 of 600 | victoria
# Processing Record 373 of 600 | burica
# Processing Record 374 of 600 | cristobal obregon
# Processing Record 375 of 600 | luganville
# Processing Record 376 of 600 | phan thiet
# Processing Record 377 of 600 | traralgon
# Processing Record 378 of 600 | dhidhdhoo
# Processing Record 379 of 600 | gelemso
# Processing Record 380 of 600 | lebu
# Processing Record 381 of 600 | gravdal
# Processing Record 382 of 600 | pisco
# Processing Record 383 of 600 | kurbnesh
# Processing Record 384 of 600 | kazalinsk
# Processing Record 385 of 600 | vestmannaeyjar
# Processing Record 386 of 600 | san jose
# Processing Record 387 of 600 | bethel
# Processing Record 388 of 600 | bredasdorp
# Processing Record 389 of 600 | balkanabat
# Processing Record 390 of 600 | bontang
# Processing Record 391 of 600 | port elizabeth
# Processing Record 392 of 600 | malinovoye ozero
# Processing Record 393 of 600 | high level
# Processing Record 394 of 600 | rawah
# Processing Record 395 of 600 | saskylakh
# Processing Record 396 of 600 | yingcheng
# Processing Record 397 of 600 | mokhsogollokh
# Processing Record 398 of 600 | vila velha
# Processing Record 399 of 600 | norman wells
# Processing Record 400 of 600 | marcona
# Processing Record 401 of 600 | cidreira
# Processing Record 402 of 600 | nanortalik
# Processing Record 403 of 600 | vallenar
# Processing Record 404 of 600 | maceio
# Processing Record 405 of 600 | aktau
# Processing Record 406 of 600 | cap malheureux
# Processing Record 407 of 600 | severnoye
# Processing Record 408 of 600 | lishan
# Processing Record 409 of 600 | gizo
# Processing Record 410 of 600 | labytnangi
# Processing Record 411 of 600 | tura
# Processing Record 412 of 600 | walvis bay
# Processing Record 413 of 600 | kaputa
# Processing Record 414 of 600 | madison
# Processing Record 415 of 600 | hilo
# Processing Record 416 of 600 | new norfolk
# Processing Record 417 of 600 | saldanha
# Processing Record 418 of 600 | marsh harbour
# Processing Record 419 of 600 | santa cruz
# Processing Record 420 of 600 | honiara
# Processing Record 421 of 600 | iralaya
# Processing Record 422 of 600 | hualmay
# Processing Record 423 of 600 | richards bay
# Processing Record 424 of 600 | opuwo
# Processing Record 425 of 600 | kasempa
# Processing Record 426 of 600 | ialibu
# Processing Record 427 of 600 | skibbereen
# Processing Record 428 of 600 | manzhouli
# Processing Record 429 of 600 | hasaki
# Processing Record 430 of 600 | sol-iletsk
# Processing Record 431 of 600 | prieska
# Processing Record 432 of 600 | zhetybay
# Processing Record 433 of 600 | princeton
# Processing Record 434 of 600 | bathsheba
# Processing Record 435 of 600 | raga
# Processing Record 436 of 600 | port alfred
# Processing Record 437 of 600 | snasa
# Processing Record 438 of 600 | luderitz
# Processing Record 439 of 600 | tumpat
# Processing Record 440 of 600 | valverde del camino
# Processing Record 441 of 600 | grand gaube
# Processing Record 442 of 600 | nelson bay
# Processing Record 443 of 600 | mount pleasant
# Processing Record 444 of 600 | eau claire
# Processing Record 445 of 600 | fort-shevchenko
# Processing Record 446 of 600 | palabuhanratu
# Processing Record 447 of 600 | launceston
# Processing Record 448 of 600 | longyearbyen
# Processing Record 449 of 600 | teahupoo
# Processing Record 450 of 600 | impfondo
# Processing Record 451 of 600 | jabiru
# Processing Record 452 of 600 | beloha
# Processing Record 453 of 600 | syracuse
# Processing Record 454 of 600 | faya
# Processing Record 455 of 600 | nizhneyansk
# Processing Record 456 of 600 | nador
# Processing Record 457 of 600 | shkotovo-26
# Processing Record 458 of 600 | bedele
# Processing Record 459 of 600 | buchanan
# Processing Record 460 of 600 | huaiyin
# Processing Record 461 of 600 | abu samrah
# Processing Record 462 of 600 | dingle
# Processing Record 463 of 600 | ilhabela
# Processing Record 464 of 600 | bonthe
# Processing Record 465 of 600 | banjar
# Processing Record 466 of 600 | fairbanks
# Processing Record 467 of 600 | moses lake
# Processing Record 468 of 600 | puerto escondido
# Processing Record 469 of 600 | sao marcos
# Processing Record 470 of 600 | uvarovo
# Processing Record 471 of 600 | san pedro
# Processing Record 472 of 600 | zemio
# Processing Record 473 of 600 | south shields
# Processing Record 474 of 600 | vestmanna
# Processing Record 475 of 600 | saint-francois
# Processing Record 476 of 600 | utiroa
# Processing Record 477 of 600 | hay river
# Processing Record 478 of 600 | devonport
# Processing Record 479 of 600 | haines junction
# Processing Record 480 of 600 | sokolo
# Processing Record 481 of 600 | yura
# Processing Record 482 of 600 | ribeira grande
# Processing Record 483 of 600 | kerema
# Processing Record 484 of 600 | katsuura
# Processing Record 485 of 600 | svetlyy
# Processing Record 486 of 600 | qaqortoq
# Processing Record 487 of 600 | muromtsevo
# Processing Record 488 of 600 | belaya gora
# Processing Record 489 of 600 | salisbury
# Processing Record 490 of 600 | ukiah
# Processing Record 491 of 600 | kununurra
# Processing Record 492 of 600 | slave lake
# Processing Record 493 of 600 | noumea
# Processing Record 494 of 600 | marsa matruh
# Processing Record 495 of 600 | conceicao da barra
# Processing Record 496 of 600 | taylor
# Processing Record 497 of 600 | port hardy
# Processing Record 498 of 600 | taolanaro
# Processing Record 499 of 600 | labutta
# Processing Record 500 of 600 | longlac
# Processing Record 501 of 600 | eureka
# Processing Record 502 of 600 | tilichiki
# Processing Record 503 of 600 | khorramshahr
# Processing Record 504 of 600 | envira
# Processing Record 505 of 600 | coquimbo
# Processing Record 506 of 600 | natal
# Processing Record 507 of 600 | alasehir
# Processing Record 508 of 600 | radishchevo
# Processing Record 509 of 600 | nemuro
# Processing Record 510 of 600 | flinders
# Processing Record 511 of 600 | cape town
# Processing Record 512 of 600 | kyakhta
# Processing Record 513 of 600 | westport
# Processing Record 514 of 600 | srednekolymsk
# Processing Record 515 of 600 | labuhan
# Processing Record 516 of 600 | la sarre
# Processing Record 517 of 600 | hervey bay
# Processing Record 518 of 600 | bargal
# Processing Record 519 of 600 | whitefish
# Processing Record 520 of 600 | kimbe
# Processing Record 521 of 600 | monrovia
# Processing Record 522 of 600 | thunder bay
# Processing Record 523 of 600 | chapais
# Processing Record 524 of 600 | ossora
# Processing Record 525 of 600 | leh
# Processing Record 526 of 600 | pacific grove
# Processing Record 527 of 600 | narsaq
# Processing Record 528 of 600 | svetlogorsk
# Processing Record 529 of 600 | bom jesus
# Processing Record 530 of 600 | hobart
# Processing Record 531 of 600 | mabaruma
# Processing Record 532 of 600 | trincomalee
# Processing Record 533 of 600 | alexandria
# Processing Record 534 of 600 | grootfontein
# Processing Record 535 of 600 | havelock
# Processing Record 536 of 600 | klaksvik
# Processing Record 537 of 600 | upernavik
# Processing Record 538 of 600 | ganzhou
# Processing Record 539 of 600 | sabirabad
# Processing Record 540 of 600 | tolcsva
# Processing Record 541 of 600 | oskarshamn
# Processing Record 542 of 600 | castlegar
# Processing Record 543 of 600 | fujishiro
# Processing Record 544 of 600 | bulgan
# Processing Record 545 of 600 | businga
# Processing Record 546 of 600 | khasan
# Processing Record 547 of 600 | muros
# Processing Record 548 of 600 | taraz
# Processing Record 549 of 600 | makat
# Processing Record 550 of 600 | jalu
# Processing Record 551 of 600 | aklavik
# Processing Record 552 of 600 | eyl
# Processing Record 553 of 600 | umzimvubu
# Processing Record 554 of 600 | carthage
# Processing Record 555 of 600 | rocha
# Processing Record 556 of 600 | sechura
# Processing Record 557 of 600 | castro
# Processing Record 558 of 600 | kano
# Processing Record 559 of 600 | scottsbluff
# Processing Record 560 of 600 | batagay-alyta
# Processing Record 561 of 600 | ciudad bolivar
# Processing Record 562 of 600 | morgantown
# Processing Record 563 of 600 | torbay
# Processing Record 564 of 600 | bud
# Processing Record 565 of 600 | pangkalanbuun
# Processing Record 566 of 600 | yulara
# Processing Record 567 of 600 | kaitangata
# Processing Record 568 of 600 | talcahuano
# Processing Record 569 of 600 | tabiauea
# Processing Record 570 of 600 | samarai
# Processing Record 571 of 600 | pokhara
# Processing Record 572 of 600 | puerto ayora
# Processing Record 573 of 600 | lahat
# Processing Record 574 of 600 | malanje
# Processing Record 575 of 600 | bosaso
# Processing Record 576 of 600 | hryshkivtsi
# Processing Record 577 of 600 | buala
# Processing Record 578 of 600 | peleduy
# Processing Record 579 of 600 | sasaguri
# Processing Record 580 of 600 | otane
# Processing Record 581 of 600 | kruisfontein
# Processing Record 582 of 600 | atka
# Processing Record 583 of 600 | la primavera
# Processing Record 584 of 600 | volchikha
# Processing Record 585 of 600 | georgetown
# Processing Record 586 of 600 | porto novo
# Processing Record 587 of 600 | esperance
# Processing Record 588 of 600 | san cristobal
# Processing Record 589 of 600 | laguna
# Processing Record 590 of 600 | daxian
# Processing Record 591 of 600 | margate
# Processing Record 592 of 600 | uusikaupunki
# Processing Record 593 of 600 | lakhdenpokhya
# Processing Record 594 of 600 | demirci
# Processing Record 595 of 600 | dicabisagan
# Processing Record 596 of 600 | itoman
# Processing Record 597 of 600 | palana
# Processing Record 598 of 600 | mount gambier
# Processing Record 599 of 600 | sola
# Processing Record 600 of 600 | poso
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
#Now that my data was able to successfully be pulled from the API for the specific cities I pulled from the citipy module, I needed to transfer this data to the output file saved towards the beginning of my cound. 
#Performed a .count to ensure that same number of values were present for each column. The axis = 0 allows for this information to presented in a stacked layout that is better visually than the unstacked version. 
Project_Secondary_df.to_csv("City_Data.csv")
Project_Secondary_df.count(axis=0)
# Out:
# City          550
# Latitudes     550
# Longitudes    550
# Country       550
# Date          550
# Temp Max      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# dtype: int64

# %%
#Performed .head() to capture preview of completed data frame, using the data pulled from the successful API call done in my code. 
Project_Secondary_df.head()
# Out:
#                 City Latitudes Longitudes Country        Date Temp Max  \
# 2           olafsvik     64.89     -23.71      IS  1581367930    33.48
# 3      alta floresta     -9.88     -56.09      BR  1581367865     89.6
# 4  riachao das neves    -11.75     -44.91      BR  1581367930     76.5
# 5        east london    -33.02      27.91      ZA  1581367930    71.31
# 7         thalassery     11.75      75.53      IN  1581367930     73.4
#
#   Humidity Cloudiness Wind Speed
# 2       70         76      23.33
# 3       55         20       3.36
# 4       91         97       2.95
# 5       68         35       9.64
# 7       94         20       3.36

# %%
# matplotlib figures for first analysis. All of my plt functions, i've used before in my previous hw assignments. One thing that I was reminded of was that order does matter when you perform the plt.scatter function. As in the x value data set must go first and then y value data set must go second. I played around with the figure sizes to see would look the best. Other than that I used a separate folder to save my solution images. So I used the "../[insert folder location]/[insert file name]" to store the image. Something I also learned was that you have to do the plt.savefig priror to the plt.show()
plt.figure(figsize=(8,6))
plt.grid
plt.scatter(Project_Secondary_df["Latitudes"],Project_Secondary_df["Temp Max"],  edgecolor = "black", color="blue", alpha=1)
plt.ylabel("Temperature Max Values (Fahrenheit)")
plt.xlabel("Latitude")
plt.xlim(-80, 100)
plt.ylim(-100, 150)
plt.title(f"Temperature Max Values vs Latitude (2/10/20)", fontsize = 12)
plt.savefig("../Solution_Images/MaxTempVsLatitude.png", bbox_inches= "tight")
plt.show()

# %%
#Refer to notes for my first plot
plt.figure(figsize=(8,6))
plt.grid
plt.scatter(Project_Secondary_df["Latitudes"], Project_Secondary_df["Humidity"], edgecolor = "black", color="blue", alpha=1)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.xlim(-80, 100)
plt.ylim(-20, 120)
plt.title(f"Humidity Percentage vs Latitude (2/11/20)", fontsize = 12)
plt.savefig("../Solution_Images/HumidityVsLatitude.png", bbox_inches= "tight")
plt.show()

# %%
# Refer to notes from first plot 
plt.figure(figsize=(8,6))
plt.grid
plt.scatter(Project_Secondary_df["Latitudes"], Project_Secondary_df["Cloudiness"], edgecolor = "black", color="blue", alpha=1)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(-80, 100)
plt.ylim(-20, 120)
plt.title(f"Cloudiness Percentage vs Latitude (2/11/20)", fontsize = 12)
plt.show()

# %%
# Refer to notes from first plot 
plt.figure(figsize=(8,6))
plt.grid
plt.scatter(Project_Secondary_df["Latitudes"], Project_Secondary_df["Wind Speed"], edgecolor = "black", color="blue", alpha=1)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(-80, 100)
plt.ylim(-5, 40)
plt.title(f"Wind Speed vs Latitude (2/11/20)", fontsize = 12)
plt.savefig("../Solution_Images/WindSpeedVsLatitude.png", bbox_inches= "tight")
plt.show()

# %%
#Analysis 

# Trend 1: As cities latitude approached zero (which represents the equator) the maximum temperatures, of the random selected cities, were highest. The inverted quadratic shape (upside down ‘U’) of the data set also makes sense because as cities approached both positive 90 (north pole) and negative 90 (south pole), the maximum temperatures were the lowest. 


# Trend 2: There was no direct correlations between a city’s latitude and its humidity percentage and cloudiness percentage. I was able to conclude this by noticing the variance in data points across each of the latitude values represented. 

# Trend 3: The data set that compared the cities latitude and windspeed was skewed left from my perspective. What I took from that, is that as cities were further away from the equator or closer to the north pole that those cities had higher wind speeds. Another observation I noted from this data plot was that the majority of wind speeds were below 15 mph.
